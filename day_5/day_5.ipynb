# %%
# 표준 모듈 삽입
import math

# %%
print(math.cos(10))
print(math.ceil(5.6)) #숫자보다 큰 정수 중에 가장 작은 정수 (올림)
print(math.floor(5.6)) #숫자보다 작은 정수중에 가장 큰 정수 (버림)
# Out:
# -0.8390715290764524
# 6
# 5

# %%
from math import cos, ceil, floor

print(cos(10))
print(ceil(5.6)) #숫자보다 큰 정수 중에 가장 작은 정수 (올림)
print(floor(5.6)) #숫자보다 작은 정수중에 가장 큰 정수 (버림)
# Out:
# -0.8390715290764524
# 6
# 5

# %%
# random 모듈 : 임의의 수를 발생시키는 함수들을 가진 모듈
import random as rnd

print('random 모듈 : ')
#random() : 0.0 < x < 1.0 사이의 float 리턴
print('random() : ', rnd.random())

# uniform(min, max)
print('uniform() : ', rnd.uniform(10, 20))

# randrange([min], max) : min < x < max 사이의 int 리턴, 0부터 max
print('randrange() : ', rnd.randrange(10, 20))

# choice(list) : 리스트 내부의 임의의 요소를 리턴
print('choice() : ', rnd.choice(list(range(10))))

# shuffle(list) : 리스트 요소를 랜덤하게 섞음
a = list(range(10))
print('shuffle() : ', rnd.shuffle(a), a)

# sample(list, k=숫자) : 리스트에서 숫자의 갯수 요소를 랜덤하게 리턴
print('sample() : ', rnd.sample(a, k=3))
# Out:
# random 모듈 :
# random() :  0.5386061133051597
# uniform() :  11.309223801368711
# randrange() :  11
# choice() :  8
# shuffle() :  None [1, 9, 3, 4, 0, 8, 2, 6, 5, 7]
# sample() :  [8, 0, 1]

# %%
# sys 모듈 : 시스템 관련 정보를 가져 옴

import sys

print('copyright : ', sys.copyright)
print('version : ', sys.version)
sys.exit()
# Out:
# copyright :  Copyright (c) 2001-2021 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.
# version :  3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# os 모듈 : 운영체제와 관련된 명령어
import os

print('현재 운영체제 : ', os.name)
print('현재 작업 경로 : ', os.getcwd())
print('현재 폴더 리스트 : ', os.listdir())
# Out:
# 현재 운영체제 :  nt
# 현재 작업 경로 :  C:\Users\alswo\Documents\pythion_basic
# 현재 폴더 리스트 :  ['.ipynb_checkpoints', '20211223-main', 'day_3_sol.ipynb', 'day_4_sol.ipynb', 'day_5.ipynb']

# %%
# 디렉토리 생성
os.mkdir('test_dir')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '20211223-main',
#  'day_3_sol.ipynb',
#  'day_4_sol.ipynb',
#  'day_5.ipynb',
#  'test_dir']

# %%
# 디렉토리 삭제
os.rmdir('test_dir')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '20211223-main',
#  'day_3_sol.ipynb',
#  'day_4_sol.ipynb',
#  'day_5.ipynb']

# %%
# file 이름 변경 : rename(old_name, new_name)
os.rename('day_3_sol.ipynb', 'new.py')
os.listdir()

# %%
# file 삭제 : remove(파일명)
# os.remove('new.py')
# os.listdir()
# ! cd dataset
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 702B-F0FC
#
#  C:\Users\alswo\Documents\pythion_basic 디렉터리
#
# 2021-12-29  오전 10:14    <DIR>          .
# 2021-12-29  오전 10:14    <DIR>          ..
# 2021-12-29  오전 09:35    <DIR>          .ipynb_checkpoints
# 2021-12-29  오전 09:12    <DIR>          20211223-main
# 2021-12-29  오전 09:51            34,906 day_4_sol.ipynb
# 2021-12-29  오전 10:14             7,308 day_5.ipynb
# 2021-12-29  오전 09:52            20,454 new.py
#                3개 파일              62,668 바이트
#                4개 디렉터리  121,907,228,672 바이트 남음

# %%
# datetime 모듈 : 날짜를 형식에 맞게 편집 가능
import datetime as dt

print(dt.datetime.now())
print(dt.datetime.today())
# Out:
# 2021-12-29 10:23:16.707695
# 2021-12-29 10:23:16.707696

# %%
# time 모듈 : 일정 시간 멈춤
import time
print('time start ')
time.sleep(3)
print("\n time end")
# Out:
# time start
#
#  time end

# %%
# urllib 모듈 : url 라이브러리
# 인터넷 검색 1.urlopen 2.해당 데이터 road
from urllib import request

# urlopen() 구글의 메인 페이지 read
target = request.urlopen('http://www.naver.com.com')
output = target.read()

print(output)
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>      <html class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js ie lt-ie9 lt-ie8" lang="en"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js ie lt-ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->\n<!--[if IE]><!--> <html class="no-js ie" lang="en"> <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n    \n    <meta name="csrf-token" content="G3y9goM3cBmcopnTb4SLauUxDiS63htmq9O0vo9O">\n\n    <title>    Search\n | com.com</title>\n    \n    <link rel="canonical" href="https://com.com">\n    <link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32" />\n    <link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16" />\n\n    \n    <script src="/build/js/modernizr-43710f21f2.js"></script>\n\n    <link href="https://fonts.googleapis.com/css?family=Karla:400,400i,700,700i" rel="stylesheet" data-norem>\n\n        <link href="/build/css/public-083545f46e.css" rel="stylesheet">\n    <link href="/build/css/all-public-673f0fb562.css" rel="stylesheet">\n    <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n    <script>\n        (adsbygoogle = window.adsbygoogle || []).push({\n            google_ad_client: "ca-pub-4395704822686761",\n            enable_page_level_ads: true\n        });\n    </script>\n    \n    <script>\n      window.Laravel = {"csrfToken":"G3y9goM3cBmcopnTb4SLauUxDiS63htmq9O0vo9O"};\n    </script>\n\n    <script>\n        (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n        (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n        m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n        })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n\n        ga(\'create\', \'UA-89347323-1\', \'auto\');\n        ga(\'send\', \'pageview\');\n    </script>\n\n    \n    <!--[if lte IE 8]><script src="/build/js/respond-b890fb8052.js"></script><![endif]-->\n\n</head>\n\n<body>\n\n<div id="public-app" class="app-container">\n\n        \n        <layout-app\n        value=""\n    ></layout-app>\n\n\n        <noscript>\n            <div class="wrapper-medium">\n                <div class="wrapper-medium has-background-white has-drop-shadow">\n                    <h1 class="h3 color-red s--center s--margin-bottom">You need to enable JavaScript to run this website.</h1>\n                </div>\n            </div>\n        </noscript>\n\n    </div>\n\n    \n        <footer class="site-footer" role="contentinfo">\n    <nav class="site-footer-nav">\n                <div class="wrapper">\n\n            <div class="row site-footer-nav--links">\n                <div class="col-12 col-2-sm-med"></div>\n                <div class="col-12 col-6-xs col-2-sm-med">\n                    <ul class="list-nested list-reset">\n                        <li><strong><a href="https://com.com/com">Compare</a></strong>\n                            <ul>\n                                <li><a href="https://com.com/com/personal-loans">Personal Loans</a></li>\n                                <li><a href="https://com.com/com/categories">All Categories</a></li>\n                            </ul>\n                        </li>\n                    </ul>\n                </div>\n                <div class="col-12 col-6-xs col-2-sm-med">\n                    <ul class="list-nested list-reset">\n                        <li><strong>About</strong>\n                            <ul>\n                                <li><a href="https://com.com/com/how-it-works">How It Works</a></li>\n                                <li><a href="https://com.xyz/#advertiser">Advertise With Us</a></li>\ ...

# %%
# beautifulsoup4 모듈 설치하는 방법
# pip install 모듈(패키지명)
# !pip install beautifulsoup4

# %%
# <html> ~ </html> tag 형식으로 변환해 주는 모듈 : BeautifulSoup
from bs4 import BeautifulSoup

target = request.urlopen('http://www.naver.com.com')
soup = BeautifulSoup(target, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js ie lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js ie lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <!--[if IE]><!--> <html class="no-js ie" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="UcFD0SUbdahX7eXseczeLbMKjRra08JHn6MnqdPa" name="csrf-token"/>
# <title>    Search
#  | com.com</title>
# <link href="https://com.com" rel="canonical"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <script src="/build/js/modernizr-43710f21f2.js"></script>
# <link data-norem="" href="https://fonts.googleapis.com/css?family=Karla:400,400i,700,700i" rel="stylesheet"/>
# <link href="/build/css/public-083545f46e.css" rel="stylesheet"/>
# <link href="/build/css/all-public-673f0fb562.css" rel="stylesheet"/>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#         (adsbygoogle = window.adsbygoogle || []).push({
#             google_ad_client: "ca-pub-4395704822686761",
#             enable_page_level_ads: true
#         });
#     </script>
# <script>
#       window.Laravel = {"csrfToken":"UcFD0SUbdahX7eXseczeLbMKjRra08JHn6MnqdPa"};
#     </script>
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-89347323-1', 'auto');
#         ga('send', 'pageview');
#     </script>
# <!--[if lte IE 8]><script src="/build/js/respond-b890fb8052.js"></script><![endif]-->
# </link></head>
# <body>
# <div class="app-container" id="public-app">
# <layout-app value=""></layout-app>
# <noscript>
# <div class="wrapper-medium">
# <div class="wrapper-medium has-background-white has-drop-shadow">
# <h1 class="h3 color-red s--center s--margin-bottom">You need to enable JavaScript to run this website.</h1>
# </div>
# </div>
# </noscript>
# </div>
# <footer class="site-footer" role="contentinfo">
# <nav class="site-footer-nav">
# <div class="wrapper">
# <div class="row site-footer-nav--links">
# <div class="col-12 col-2-sm-med"></div>
# <div class="col-12 col-6-xs col-2-sm-med">
# <ul class="list-nested list-reset">
# <li><strong><a href="https://com.com/com">Compare</a></strong>
# <ul>
# <li><a href="https://com.com/com/personal-loans">Personal Loans</a></li>
# <li><a href="https://com.com/com/categories">All Categories</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="col-12 col-6-xs col-2-sm-med">
# <ul class="list-nested list-reset">
# <li><strong>About</strong>
# <ul>
# <li><a href="https://com.com/com/how-it-works">How It Works</a></li>
# <li><a href="https://com.xyz/#advertiser">Advertise With Us</a></li>
# <li><a href="https://com.xyz/#publisher">Publisher Sign Up</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="col-12 col-6-xs col-2-sm-med">
# <ul class="list-nested list-reset">
# <li><strong>Legal</strong>
# <ul>
# <li><a href="https://com.com/terms">Terms Of Use</a></li>
# <li><a href="https://com.com/privacy">Privacy Policy</a></li>
# <li><a href="https://com.com/legal">Legal</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="col-12 col-6-xs col-2-sm-med">
# <ul class="list-nested list-reset">
# <li><strong>Account</strong>
# <ul>
# <li>Coming Soon</li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="col-12 col-2-sm-med"></div>
# </div>
# </div>
# </nav>
# <div class="wrapper site-footer--info">
# <div class="row">
# <div class="col-12 col-6-med site-footer--logo">
# <a class="site-logo" href="https://com.com/com">
# <img alt="com.com" class="site-logo--image" onerror="this.src='/images/comcom-color-logo.png';this.onerror=null;" src="/images/comcom-color-logo.svg"/>
# </a>
# </div>
# <div class="col-12 col-6-med site-footer--copyright">
# <p class="text--small">© Copyright 2021 com.com. All rights reserved.</p>
# </div>
# </div>
# </div>
# </footer>
# <script src="/build/js/public-8412ab8277.js"></script>
# <!--[if lte IE 8]><script src="/build/js/rem-f6062a8798.js"></script><![endif]-->
# </body>
# </html>
# </html>

# %%
# 기상청 날씨 예보를 가져와서 보여 줌
# url에 연결 -> urllib.request.urlopen(url명)
from urllib import request
from bs4 import BeautifulSoup

url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108'
target = request.urlopen(url)

soup = BeautifulSoup(target, 'html.parser')

# %%
for location in soup.select('location'):
    print('도시 :', location.select_one('city').string)
    print('날씨 :', location.select_one('wf').string)
    print('최저기온 :', location.select_one('tmn').string)
    print('최고기온 :', location.select_one('tmx').string)
# Out:
# 도시 : 서울
# 날씨 : 구름많음
# 최저기온 : -9
# 최고기온 : 0
# 도시 : 인천
# 날씨 : 구름많음
# 최저기온 : -8
# 최고기온 : 0
# 도시 : 수원
# 날씨 : 구름많음
# 최저기온 : -10
# 최고기온 : 1
# 도시 : 파주
# 날씨 : 구름많음
# 최저기온 : -15
# 최고기온 : 0
# 도시 : 이천
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 0
# 도시 : 평택
# 날씨 : 구름많음
# 최저기온 : -11
# 최고기온 : 1
# 도시 : 춘천
# 날씨 : 구름많음
# 최저기온 : -14
# 최고기온 : 0
# 도시 : 원주
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 0
# 도시 : 강릉
# 날씨 : 구름많음
# 최저기온 : -6
# 최고기온 : 5
# 도시 : 대전
# 날씨 : 구름많음
# 최저기온 : -9
# 최고기온 : 2
# 도시 : 세종
# 날씨 : 구름많음
# 최저기온 : -10
# 최고기온 : 1
# 도시 : 홍성
# 날씨 : 구름많음
# 최저기온 : -10
# 최고기온 : 2
# 도시 : 청주
# 날씨 : 구름많음
# 최저기온 : -9
# 최고기온 : 1
# 도시 : 충주
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 0
# 도시 : 영동
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 2
# 도시 : 광주
# 날씨 : 구름많음
# 최저기온 : -5
# 최고기온 : 5
# 도시 : 목포
# 날씨 : 구름많음
# 최저기온 : -3
# 최고기온 : 4
# 도시 : 여수
# 날씨 : 구름많음
# 최저기온 : -3
# 최고기온 : 5
# 도시 : 순천
# 날씨 : 구름많음
# 최저기온 : -4
# 최고기온 : 6
# 도시 : 광양
# 날씨 : 구름많음
# 최저기온 : -4
# 최고기온 : 6
# 도시 : 나주
# 날씨 : 구름많음
# 최저기온 : -7
# 최고기온 : 4
# 도시 : 전주
# 날씨 : 구름많음
# 최저기온 : -7
# 최고기온 : 3
# 도시 : 군산
# 날씨 : 구름많음
# 최저기온 : -7
# 최고기온 : 3
# 도시 : 정읍
# 날씨 : 구름많음
# 최저기온 : -8
# 최고기온 : 2
# 도시 : 남원
# 날씨 : 구름많음
# 최저기온 : -8
# 최고기온 : 4
# 도시 : 고창
# 날씨 : 구름많음
# 최저기온 : -6
# 최고기온 : 3
# 도시 : 무주
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 2
# 도시 : 부산
# 날씨 : 구름많음
# 최저기온 : -4
# 최고기온 : 6
# 도시 : 울산
# 날씨 : 구름많음
# 최저기온 : -5
# 최고기온 : 5
# 도시 : 창원
# 날씨 : 구름많음
# 최저기온 : -5
# 최고기온 : 4
# 도시 : 진주
# 날씨 : 구름많음
# 최저기온 : -8
# 최고기온 : 5
# 도시 : 거창
# 날씨 : 구름많음
# 최저기온 : -10
# 최고기온 : 5
# 도시 : 통영
# 날씨 : 구름많음
# 최저기온 : -4
# 최고기온 : 5
# 도시 : 대구
# 날씨 : 구름많음
# 최저기온 : -7
# 최고기온 : 4
# 도시 : 안동
# 날씨 : 구름많음
# 최저기온 : -12
# 최고기온 : 2
# 도시 : 포항
# 날씨 : 구름많음
# 최저기온 : -5
# 최고기온 : 6
# 도시 : 경주
# 날씨 : 구름많음
# 최저기온 : -8
# 최고기온 : 5
# 도시 : 울진
# 날씨 : 구름많음
# 최저기온 : -6
# 최고기온 : 6
# 도시 : 울릉도
# 날씨 : 구름많음
# 최저기온 : -1
# 최고기온 : 4
# 도시 : 제주
# 날씨 : 구름많음
# 최저기온 : 3
# 최고기온 : 8
# 도시 : 서귀포
# 날씨 : 구름많음
# 최저기온 : 3
# 최고기온 : 10

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\programdata\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from flask) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from flask) (2.0.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->flask) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello():
    return "<h1>Hello World!!</h1>"

# %%
def test(function):
    def wrapper():
        print("hello start!!! ")
        function()
        print("hello end!!!")
    return wrapper
# 데코레이션 함수

@test
def hello():
    print("Hello")
# 함수 호출
hello()
# Out:
# hello start!!!
# Hello
# hello end!!!

# %%
#모듈 만들기
os.mkdir('')

# %%
#내가 만든 패키지 모듈 불러오기
#import 패키지명.모듈명
import test_package.module_a as a
import test_package.module_b as b

print(a.variable_a)
print(b.variable_b)
# Out:
# a 모듈의 변수
# b 모듈의 변수

# %%
from test_package import *

print('module_a : ', module_a.variable_a)
print('module_b : ', module_b.variable_b)
# Out:
# module_a :  a 모듈의 변수
# module_b :  b 모듈의 변수

# %%
# 이미지 읽고 저장하기
from urllib import request

# 이미지 가져오기
target = request.urlopen('https://i3.ruliweb.com/img/21/06/19/17a23356d2e386407.jpg')
output = target.read()
print(output)

# 가져온 이미지 저장
file = open("output.jpg",'wb')
file.write(output)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xfe\x00;CREATOR: gd-jpeg v1.0 (using IJG JPEG v62), quality = 85\n\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00CX\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfa\x97m\x1bjP\xbcQ\xb7\xb0\xae\xa5\xb1\xca\xd6\xa4[z\xd1\xb7\xda\xa6\x0b\xe9F\xde\x0f\x14\xc5b\x02\xb4\xdd\xbe\xd5cm&\xda\x02\xc5}\x9di\nU\x8d\xbe\xd4\x9bh\xb8X\xacS\x8aiJ\xb4R\x98W\x8a\x13\x0b\x15\nqP\xbc}\xb1W\xd9{\xe2\xa2t\xe0\xd3@f\xbcu\x13G\xd6\xb4$OAQ4|U\\V)\xaa`\xd7C\xe1\xb96\xbe\xcc\xf0k\x1ff*\xf6\x94\xde]\xc2\x9aRW@\xb4gE\xa8\xc2&\xb3\x923\xddk\x87h\x8a\xb1\x07\xb1\xc1\xae\xfc|\xf1\xfdEr:\xa4\x1e]\xf4\x83\x1c\x13\x91YS}\x0b\xa8\xb5\xb9F4\x1e\x95<iK\x1a\x8a\x95\x05Y(X\xd6\xa7\x8di\xa8\xb5*\nC\x1e\x83\x15*\x8ab\n\x95:P493\xd4\xd4\x8bLZz\xd4\x8cr\xd3\xd7\xa51zS\xeaJ\x14R\x83\x8ei\x05\x1e\xd4\x024\xa3!\xa3\x04U[\x8f\x92\xe1_\xb1\xe2\xa5\xb2l\xc7\x8fJK\xd5\xcc[\xbb\x8ej#\xa3*Z\xc6\xe4\xf1\xfd\xde\xb4\xa3\xa5El\xdb\x90T\xbfJ\x96\xac\xcb\x8e\xa8Z(\xa2\x90\xc2\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x08oc\xf3m]=Edh\xd2\x18\xee\x8a\x13\xc3\x0f\xd6\xb7;b\xb9\xeb\x80m\xb5"G\x006\x7f\n\xda\x96\xa9\xc4\xc2\xae\x8dH\xe8{Q\xda\x923\xb9\x01\x1e\x94\xbd\xab\x13d-\x14Q@\xc2\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x0c%\x18\x1czR\xe3\x8ar\x8e\x07\xd2\x9d\x8e8\xae\x94s\xbd\xc6m\xf4\xa3\x1cS\xf1\xf9Q\x8e\xbc\xd3$\x8c-&\xde*\\f\x93\x14\x01\x16\xda6\xfe\x95&(\xc5+\x81\x16\xde\xb4\xdd\xb9\xa9\x80\xc8\xa4#\x8a`@V\xa3d\xab${S\n\xd0;\x14\xdd*&N\x08\xab\xae\xbdj&Zi\x93b\x99L\xf4\xa9 \xf9\\\x1ay\\P\xab\x83T\x16:K\'\xdfn\x0f\xb5d\xf8\x82\x1cJ\xb2z\xf0j\xf6\x8e\xf9\x8fnzR\xeb1o\xb5c\x8c\x91\xcd`\xb4\x91\xa3\xd6\'6\xa2\xa4@h\xdb\xcd<\x0e+B\x07(\xe6\xa5Zb\xd3\xd6\x80$J\x91zTj*A\xd2\xa4\xa4<w\xa7/\xe3L\x1di\xe3\x8a\x00p\xa7\n`\xebN\x1e\xd5%\x0e\x07\x8e\x94\xa2\x9a0)GZ\x00\xb3d\xdf9_Z\xb5 \xccd\x1e\xf5\x9f\x0bm\x91Mi\x0eED\xb4w.\x1a\xab\x15l\x8e\x01C\xd8\xd5\xaa\xa6>K\xb6\x1d\x9a\xae\x0eE)\xf7\x08maGJ))jK\n(\xa2\x80\n(\xa ...
